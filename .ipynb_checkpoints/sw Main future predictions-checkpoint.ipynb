# %%
# https://www.kaggle.com/muhammedazamkhan/interactive-data-visualization-nyc-taxi-trip

from __future__ import division
# pandas - Loading the data, data pre-processing
import pandas as pd
import numpy as np
import scipy.stats as scipy
# Matplotlib and Seaborn : Data visualization
import matplotlib.pyplot as plt
import requests #download from football data
import io 
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Load the data

# %%
# Read data
df = pd.read_csv("./Data/E0_18_19.csv")

# %%
df.columns
# Out:
# Index(['Div', 'Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG',
#        'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC',
#        'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD',
#        'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA',
#        'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD',
#        'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5',
#        'BbAv<2.5', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA',
#        'PSCH', 'PSCD', 'PSCA'],
#       dtype='object')

# %% [markdown]
# ### Cleaning and subsetting required data
# Remove betting data as we don't need it for prediction.

# %%
# iloc gets rows (or columns) at particular positions in the index (so it only takes integers).
result_16 = df.iloc[:,:23]
# Axis 0 will act on all the ROWS in each COLUMN
# Axis 1 will act on all the COLUMNS in each ROW
result_16 = result_16.drop(['Div','Date'],axis=1)

# 7 is FTR - so selects as far over as FTR
table_features = df.iloc[:,:7]
table_features = table_features.drop(['FTHG','FTAG','Div','Date'],axis=1)
# All beating columns
bet_16 = df.iloc[:,23:]

# %%
# Contains - 'HomeTeam', 'AwayTeam', 'FTR' 
table_features.columns
# Out:
# Index(['HomeTeam', 'AwayTeam', 'FTR'], dtype='object')

# %%
result_16.head()
feature_table = df.iloc[:,:23]

# %%
# Contains columns from HomeTeam to AR (Away Team Red Cards)
result_16.tail()
# Out:
#        HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR   Referee  HS  \
# 264     Burnley       Tottenham     2     1   H     0     0   D    M Dean  10
# 265   Leicester  Crystal Palace     1     4   A     0     1   A  A Taylor  27
# 266   Newcastle    Huddersfield     2     0   H     0     0   D  K Friend  29
# 267     Arsenal     Southampton     2     0   H     2     0   H   G Scott  12
# 268  Man United       Liverpool     0     0   D     0     0   D  M Oliver   6
#
#     ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 264 ...    4    6   9  12   7   6   1   3   0   0
# 265 ...    5    5   7  14   8   3   2   1   0   0
# 266 ...   12    1  11   7  12   0   2   0   0   1
# 267 ...    4    4   7  14   6   4   0   0   0   0
# 268 ...    3    1  15  17   3   7   1   3   0   0
#
# [5 rows x 21 columns]

# %%
# 0) Team, 1) Home Goals Score, 2) Away Goals Score, 3) Home Attack Strength 
# 4) Away Attack Strength 5) Home Goals Conceded, 6) Away Goals Conceded, 
# 7) Home Defensive Strenght, 8) Away Defensive Strength
# New table of columns created
table_16 = pd.DataFrame(columns=('Team','HGS','AGS','HAS','AAS','HGC','AGC','HDS','ADS',))
print(table_16)
# Out:
# Empty DataFrame
# Columns: [Team, HGS, AGS, HAS, AAS, HGC, AGC, HDS, ADS]
# Index: []

# %%
# Number of rows in csv file
result_16.shape[0]
# Out:
# 269

# %%
# Full Time Home Goals total divided by / number of rows
avg_home_scored_16 = result_16.FTHG.sum()*1.0 / result_16.shape[0]
# Full Time Away Goals total divided by / number of rows
avg_away_scored_16 = result_16.FTAG.sum()*1.0 / result_16.shape[0]
#
avg_home_conceded_16 = avg_away_scored_16
#
avg_away_conceded_16 = avg_home_scored_16
print("Average number of goals at home",avg_home_scored_16)
print("Average number of goals away", avg_away_scored_16)
print("Average number of goals conceded at home",avg_home_conceded_16)
print("Average number of goals conceded away",avg_away_conceded_16)
# Out:
# Average number of goals at home 1.553903345724907
# Average number of goals away 1.278810408921933
# Average number of goals conceded at home 1.278810408921933
# Average number of goals conceded away 1.553903345724907

# %%
# Grouping HomeTeam and AwayTeam
# Result home - is grouped by 'HomeTeam' and declared an index of the new table: Result Home table.
# Result Away - is grouped by 'AwayTeam' and declared an index of the new table: Result Away table.

result_home = result_16.groupby('HomeTeam', as_index=True)
result_away = result_16.groupby('AwayTeam', as_index=True)

# %%
#list(result_home)[0]
result_16.columns
# Out:
# Index(['HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR',
#        'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY',
#        'HR', 'AR'],
#       dtype='object')

# %%
result_home = result_16.groupby('HomeTeam', as_index=True).agg(np.sum)
result_home
# Out:
#                 FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  AC  \
# HomeTeam
# Arsenal           30    11     9     6  187  160   70   53  160  193   84  69
# Bournemouth       26    18    14     7  174  175   66   58  137  167   74  71
# Brighton          16    15     9     7  136  157   41   53  162  114   60  64
# Burnley           17    23    11    10  144  204   47   70  131  144   50  76
# Cardiff           16    28     6    15  175  174   48   70  148  178   68  85
# Chelsea           26     9    12     4  218  113   82   39  111  142   75  58
# Crystal Palace     9    12     5     2  211  133   55   37  129  143  101  52
# Everton           21    21     9    11  199  145   54   56  162  182   86  53
# Fulham            17    26     8    13  214  159   70   73  149  104   74  59
# Huddersfield       6    22     4    14  150  156   43   62  152  147   63  48
# Leicester         14    17     7    11  198  127   64   44  135  131   78  57
# Liverpool         35     7    17     4  230   89   89   27  122  119   93  39
# Man City          49    11    25     7  286   88  112   31  123  109  100  28
# Man United        25    16    13     4  201  129   95   54  150  155   83  54
# Newcastle         14    18     5     8  188  156   52   47  155  143   85  73
# Southampton       15    21     7     8  176  157   64   55  151  136   69  71
# Tottenham         24    12    10     4  196  158   75   60  121  112   72  59
# Watford           17    18     5     8  150  131   55   55  152  134   64  68
# West Ham          21    20     7     9  188  149   69   65  133  136   90  60
# Wolves            20    19     4     8  193  172   63   61  160  116   73  70
#
#                 HY  AY  HR  AR
# HomeTeam
# Arsenal         25  31   0   1
# Bournemouth     28  29   1   3
# Brighton        23  17   1   1
# Burnley         22  24   0   1
# Cardiff         25  26   0   2
# Chelsea         14  21   0   0
# Crystal Palace  17  23   1   0
# Everton         20  32   0   0
# Fulham          25  19   1   0
# Huddersfield    16  29   3   2
# Leicester       27  18   2   4
# Liverpool       11  21   1   0
# Man City        12  20   0   1
# Man United      20  22   1   1
# Newcastle       19  27   1   1
# Southampton     30  22   2   1
# Tottenham       13  19   0   1
# Watford         19  14   1   3
# West Ham        21  20   0   0
# Wolves          28  27   0   1

# %%
result_away = result_16.groupby('AwayTeam', as_index=True).agg(np.sum)
result_away
# Out:
#                 FTHG  FTAG  HTHG  HTAG   HS   AS  HST  AST   HF   AF   HC  AC  \
# AwayTeam
# Arsenal           26    25    16    12  184  141   76   54  142  138   66  54
# Bournemouth       30    12    16     7  183  150   66   49  163   99   77  77
# Brighton          24    12    11     6  236  121   68   42  120  176   74  50
# Burnley           25    14     8     5  276  112   91   38  142  131  109  42
# Cardiff           24     9     7     1  215  121   82   36  132  129   96  48
# Chelsea           20    19     9     8  124  188   47   55  170  121   40  67
# Crystal Palace    23    22     6     8  210  142   66   50  139  156   87  56
# Everton           18    15     5     6  153  133   53   55  155  140   72  64
# Fulham            35     9    17     5  249  119   87   42  138  160  102  38
# Huddersfield      28     8    13     5  196  139   73   42  137  146   70  52
# Leicester         21    18    12     3  180  158   58   63  153  120   82  81
# Liverpool          8    24     3     8  135  168   42   76  144  133   52  81
# Man City           9    25     3    16   91  177   37   71  122  111   38  97
# Man United        19    27    12    16  221  167   74   79  154  165   74  62
# Newcastle         16    10     5     8  221  113   68   43  113  155  104  43
# Southampton       25    13    14     6  206  174   77   60  131  145   84  58
# Tottenham         15    31     4    17  173  171   58   68  159  147   79  67
# Watford           17    22     9    10  196  157   61   47  158  168   92  68
# West Ham          20    14     8     8  211  126   76   44  158  118   73  48
# Wolves            15    15     9     5  154  155   54   56  113  147   71  61
#
#                 HY  AY  HR  AR
# AwayTeam
# Arsenal         21  21   0   0
# Bournemouth     30  14   3   0
# Brighton        14  19   1   2
# Burnley         16  33   1   1
# Cardiff         10  20   1   1
# Chelsea         26  19   0   0
# Crystal Palace  23  28   2   1
# Everton         21  25   2   4
# Fulham          16  23   0   1
# Huddersfield    27  21   0   1
# Leicester       25  20   1   2
# Liverpool       14  15   1   1
# Man City        18  22   1   1
# Man United      27  32   0   2
# Newcastle        9  20   0   1
# Southampton     18  24   0   1
# Tottenham       25  25   0   1
# Watford         22  31   0   1
# West Ham        24  24   0   1
# Wolves          29  25   2   1

# %%
# Won't use mean***************
# result_home = result_16.groupby('HomeTeam', as_index=True).agg(np.mean)
# result_home

# %%
# Won't use mean***************
# result_away = result_16.groupby('AwayTeam', as_index=True).agg(np.mean)
# result_away

# %%
# Home Team  
table_16.Team = result_home.index.values
# Home Goals Score
table_16.HGS = result_home.FTHG.values
# Home Goals Conceded 
table_16.HGC = result_home.FTAG.values
# Attack Goals Strength
table_16.AGS = result_away.FTAG.values
# Away Goals Conceded
table_16.AGC = result_away.FTHG.values
# Home Attack Strength
# table_16.HAS = result_away.FTHG.values
# Display
table_16
# Out:
#               Team  HGS  AGS  HAS  AAS  HGC  AGC  HDS  ADS
# 0          Arsenal   30   25  NaN  NaN   11   26  NaN  NaN
# 1      Bournemouth   26   12  NaN  NaN   18   30  NaN  NaN
# 2         Brighton   16   12  NaN  NaN   15   24  NaN  NaN
# 3          Burnley   17   14  NaN  NaN   23   25  NaN  NaN
# 4          Cardiff   16    9  NaN  NaN   28   24  NaN  NaN
# 5          Chelsea   26   19  NaN  NaN    9   20  NaN  NaN
# 6   Crystal Palace    9   22  NaN  NaN   12   23  NaN  NaN
# 7          Everton   21   15  NaN  NaN   21   18  NaN  NaN
# 8           Fulham   17    9  NaN  NaN   26   35  NaN  NaN
# 9     Huddersfield    6    8  NaN  NaN   22   28  NaN  NaN
# 10       Leicester   14   18  NaN  NaN   17   21  NaN  NaN
# 11       Liverpool   35   24  NaN  NaN    7    8  NaN  NaN
# 12        Man City   49   25  NaN  NaN   11    9  NaN  NaN
# 13      Man United   25   27  NaN  NaN   16   19  NaN  NaN
# 14       Newcastle   14   10  NaN  NaN   18   16  NaN  NaN
# 15     Southampton   15   13  NaN  NaN   21   25  NaN  NaN
# 16       Tottenham   24   31  NaN  NaN   12   15  NaN  NaN
# 17         Watford   17   22  NaN  NaN   18   17  NaN  NaN
# 18        West Ham   21   14  NaN  NaN   20   20  NaN  NaN
# 19          Wolves   20   15  NaN  NaN   19   15  NaN  NaN

# %%
#Assuming number of home games = number of away games
num_games = result_16.shape[0]/20

# %%
table_16.HAS = (table_16.HGS / num_games) / avg_home_scored_16
table_16.AAS = (table_16.AGS / num_games) / avg_away_scored_16
table_16.HDS = (table_16.HGC / num_games) / avg_home_conceded_16
table_16.ADS = (table_16.AGC / num_games) / avg_away_conceded_16
table_16
# Out:
#               Team  HGS  AGS       HAS       AAS  HGC  AGC       HDS       ADS
# 0          Arsenal   30   25  1.435407  1.453488   11   26  0.639535  1.244019
# 1      Bournemouth   26   12  1.244019  0.697674   18   30  1.046512  1.435407
# 2         Brighton   16   12  0.765550  0.697674   15   24  0.872093  1.148325
# 3          Burnley   17   14  0.813397  0.813953   23   25  1.337209  1.196172
# 4          Cardiff   16    9  0.765550  0.523256   28   24  1.627907  1.148325
# 5          Chelsea   26   19  1.244019  1.104651    9   20  0.523256  0.956938
# 6   Crystal Palace    9   22  0.430622  1.279070   12   23  0.697674  1.100478
# 7          Everton   21   15  1.004785  0.872093   21   18  1.220930  0.861244
# 8           Fulham   17    9  0.813397  0.523256   26   35  1.511628  1.674641
# 9     Huddersfield    6    8  0.287081  0.465116   22   28  1.279070  1.339713
# 10       Leicester   14   18  0.669856  1.046512   17   21  0.988372  1.004785
# 11       Liverpool   35   24  1.674641  1.395349    7    8  0.406977  0.382775
# 12        Man City   49   25  2.344498  1.453488   11    9  0.639535  0.430622
# 13      Man United   25   27  1.196172  1.569767   16   19  0.930233  0.909091
# 14       Newcastle   14   10  0.669856  0.581395   18   16  1.046512  0.765550
# 15     Southampton   15   13  0.717703  0.755814   21   25  1.220930  1.196172
# 16       Tottenham   24   31  1.148325  1.802326   12   15  0.697674  0.717703
# 17         Watford   17   22  0.813397  1.279070   18   17  1.046512  0.813397
# 18        West Ham   21   14  1.004785  0.813953   20   20  1.162791  0.956938
# 19          Wolves   20   15  0.956938  0.872093   19   15  1.104651  0.717703

# %%
table_16[table_16.Team == "Everton"]
# Out:
#       Team  HGS  AGS       HAS       AAS  HGC  AGC      HDS       ADS
# 7  Everton   21   15  1.004785  0.872093   21   18  1.22093  0.861244

# %%
table_16.head()
# Out:
#           Team  HGS  AGS       HAS       AAS  HGC  AGC       HDS       ADS
# 0      Arsenal   30   25  1.435407  1.453488   11   26  0.639535  1.244019
# 1  Bournemouth   26   12  1.244019  0.697674   18   30  1.046512  1.435407
# 2     Brighton   16   12  0.765550  0.697674   15   24  0.872093  1.148325
# 3      Burnley   17   14  0.813397  0.813953   23   25  1.337209  1.196172
# 4      Cardiff   16    9  0.765550  0.523256   28   24  1.627907  1.148325

# %%
has_plot = sns.barplot(table_16.Team,table_16.AGS) # table_16.Team
for item in has_plot.get_xticklabels():
    item.set_rotation(90)

# %%
# Building a feature dataframe
# So getting data and appending to the end of the dataframe/ feature table

''' feature_table contains all the fixtures in the season.
ftr = full time result
hst = home shots on target
ast = away shots on target
'''
feature_table = feature_table[['HomeTeam','AwayTeam','FTR','HST','AST']]

f_HAS = []
f_HDS = []
f_AAS = []
f_ADS = []
for index,row in feature_table.iterrows():
    f_HAS.append(table_16[table_16['Team'] == row['HomeTeam']]['HAS'].values[0])
    f_HDS.append(table_16[table_16['Team'] == row['HomeTeam']]['HDS'].values[0])
    f_AAS.append(table_16[table_16['Team'] == row['AwayTeam']]['AAS'].values[0])
    f_ADS.append(table_16[table_16['Team'] == row['AwayTeam']]['ADS'].values[0])
    
feature_table['HAS'] = f_HAS
feature_table['HDS'] = f_HDS
feature_table['AAS'] = f_AAS
feature_table['ADS'] = f_ADS

# %%
feature_table.head(26)
# Out:
#           HomeTeam        AwayTeam FTR  HST  AST       HAS       HDS  \
# 0       Man United       Leicester   H    6    4  1.196172  0.930233
# 1      Bournemouth         Cardiff   H    4    1  1.244019  1.046512
# 2           Fulham  Crystal Palace   A    6    9  0.813397  1.511628
# 3     Huddersfield         Chelsea   A    1    4  0.287081  1.279070
# 4        Newcastle       Tottenham   A    2    5  0.669856  1.046512
# 5          Watford        Brighton   H    5    0  0.813397  1.046512
# 6           Wolves         Everton   D    4    5  0.956938  1.104651
# 7          Arsenal        Man City   A    3    8  1.435407  0.639535
# 8        Liverpool        West Ham   H    8    2  1.674641  0.406977
# 9      Southampton         Burnley   D    3    6  0.717703  1.220930
# 10         Cardiff       Newcastle   D    1    6  0.765550  1.627907
# 11         Chelsea         Arsenal   H   11    6  1.244019  0.523256
# 12         Everton     Southampton   H    7    4  1.004785  1.220930
# 13       Leicester          Wolves   H    2    3  0.669856  0.988372
# 14       Tottenham          Fulham   H   11    3  1.148325  0.697674
# 15        West Ham     Bournemouth   A    5    5  1.004785  1.162791
# 16        Brighton      Man United   H    3    3  0.765550  0.872093
# 17         Burnley         Watford   A    3    6  0.813397  1.337209
# 18        Man City    Huddersfield   H   14    1  2.344498  0.639535
# 19  Crystal Palace       Liverpool   A    2    6  0.430622  0.697674
# 20         Arsenal        West Ham   H   10    5  1.435407  0.639535
# 21     Bournemouth         Everton   D    5    3  1.244019  1.046512
# 22    Huddersfield         Cardiff   D    1    4  0.287081  1.279070
# 23       Liverpool        Brighton   H    8    2  1.674641  0.406977
# 24     Southampton       Leicester   A    5    5  0.717703  1.220930
# 25          Wolves        Man City   D    2    6  0.956938  1.104651
#
#          AAS       ADS
# 0   1.046512  1.004785
# 1   0.523256  1.148325
# 2   1.279070  1.100478
# 3   1.104651  0.956938
# 4   1.802326  0.717703
# 5   0.697674  1.148325
# 6   0.872093  0.861244
# 7   1.453488  0.430622
# 8   0.813953  0.956938
# 9   0.813953  1.196172
# 10  0.581395  0.765550
# 11  1.453488  1.244019
# 12  0.755814  1.196172
# 13  0.872093  0.717703
# 14  0.523256  1.674641
# 15  0.697674  1.435407
# 16  1.569767  0.909091
# 17  1.279070  0.813397
# 18  0.465116  1.339713
# 19  1.395349  0.382775
# 20  0.813953  0.956938
# 21  0.872093  0.861244
# 22  0.523256  1.148325
# 23  0.697674  1.148325
# 24  1.046512  1.004785
# 25  1.453488  0.430622

# %%
def transformResult(row):
    '''Converts results (H,A or D) into numeric values'''
    if(row.FTR == 'H'):
        return 1
    elif(row.FTR == 'A'):
        return -1
    else:
        return 0

# %%
# Converting from H, D, A into numeric value
# lamba more powerful way - for each row in table
feature_table["Result"] = feature_table.apply(lambda row: transformResult(row),axis=1)

# %% [markdown]
# ### Building to this point

# %% [markdown]
# ### Training from here down

# %%
## Training from here down
# Result column at the end shows the FTR result as 1,-1 or 0   
feature_table.tail(10)
# Out:
#         HomeTeam        AwayTeam FTR  HST  AST       HAS       HDS       AAS  \
# 259    Tottenham       Leicester   H    5    9  1.148325  0.697674  1.046512
# 260       Wolves       Newcastle   D    6    3  0.956938  1.104651  0.581395
# 261      Cardiff         Watford   A    6    7  0.765550  1.627907  1.279070
# 262     West Ham          Fulham   H    7    5  1.004785  1.162791  0.523256
# 263  Bournemouth          Wolves   D    3    2  1.244019  1.046512  0.872093
# 264      Burnley       Tottenham   H    4    6  0.813397  1.337209  1.802326
# 265    Leicester  Crystal Palace   A    5    5  0.669856  0.988372  1.279070
# 266    Newcastle    Huddersfield   H   12    1  0.669856  1.046512  0.465116
# 267      Arsenal     Southampton   H    4    4  1.435407  0.639535  0.755814
# 268   Man United       Liverpool   D    3    1  1.196172  0.930233  1.395349
#
#           ADS  Result
# 259  1.004785       1
# 260  0.765550       0
# 261  0.813397      -1
# 262  1.674641       1
# 263  0.717703       0
# 264  0.717703       1
# 265  1.100478      -1
# 266  1.339713       1
# 267  1.196172       1
# 268  0.382775       0

# %%
# Season 2018-2019
# X_train = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][:230]# 
# y_train = feature_table['Result'][:230]

# X_test = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][230: 259]# 
# y_test = feature_table['Result'][230:259]

# X_predict = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][259:]# 
# y_predict = feature_table['Result'][259:]

# %%
# Season 2016-2017 / Season 2017-2018
# split data into X and y
X_train = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][:370]#
y_train = feature_table['Result'][:370]
# X_train = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][:300]#
# y_train = feature_table['Result'][:300]

X_test = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][270: 370]# 
y_test = feature_table['Result'][270:370]
# X_test = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][300: 370]# 
# y_test = feature_table['Result'][300:370]

X_predict = feature_table[['HST','AST','HAS','HDS','AAS','ADS',]][370:]# 
y_predict = feature_table['Result'][370:]

# %%
len(feature_table)
# Out:
# 269

# %%
len(X_test)
# Out:
# 0

# %%
# sklearn.metrics - F1 score, is a measure of a test's accuracy

from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import voting_classifier
from sklearn.svm import LinearSVC

# %%
clf1 = XGBClassifier()

# %%
# cross validation - runs it multiple time and takes the average , cv= 10, validating, 69 is the last run
# 60 is the aveverage over all the result, average of all the runs

y_pred = clf1.fit(X_train, y_train).predict(X_train)
accuracy_score(y_pred,y_train)
scores = cross_val_score(clf1, X_train, y_train, cv=10)
print(scores)
print(scores.mean())
# Out:
# [0.65517241 0.67857143 0.57142857 0.60714286 0.57692308 0.53846154
#  0.61538462 0.53846154 0.61538462 0.69230769]
# 0.6089238347859036

# %%
### Training here
#KNN
plot_scores_knn = []
for b in range(1,50):
    clf_knn = KNeighborsClassifier(n_neighbors=b)
    clf_knn.fit(X_train,y_train)
    scores = accuracy_score(y_test,clf_knn.predict(X_test))
    plot_scores_knn.append(scores)

#XGBClassifier
plot_scores_XGB = []
for i in range(1,100):
    clf_XGB = XGBClassifier(n_estimators=i,max_depth=100)
    clf_XGB.fit(X_train, y_train)
    scores = accuracy_score(y_test,clf_XGB.predict(X_test))
    plot_scores_XGB.append(scores)
    
#Logistic Regression
plot_scores_logreg= []
cs = [0.01,0.02,0.1,0.5,1,3,4,5,10]
for c in cs:
    clf_logreg = LogisticRegression(C=c,solver='lbfgs',multi_class='ovr')
    clf_logreg.fit(X_train, y_train)
    scores = accuracy_score(y_test,clf_logreg.predict(X_test))
    plot_scores_logreg.append(scores)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-b347a935a80c> in <module>
#       5     clf_knn = KNeighborsClassifier(n_neighbors=b)
#       6     clf_knn.fit(X_train,y_train)
# ----> 7     scores = accuracy_score(y_test,clf_knn.predict(X_test))
#       8     plot_scores_knn.append(scores)
#       9
#
# ~\Anaconda3\lib\site-packages\sklearn\neighbors\classification.py in predict(self, X)
#     145             Class labels for each data sample.
#     146         """
# --> 147         X = check_array(X, accept_sparse='csr')
#     148
#     149         neigh_dist, neigh_ind = self.kneighbors(X)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     575                              " minimum of %d is required%s."
#     576                              % (n_samples, shape_repr, ensure_min_samples,
# --> 577                                 context))
#     578
#     579     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 6)) while a minimum of 1 is required.

# %%
plot_scores_rand = []
rand_f = RandomForestClassifier()
rand_f.fit(X_train, y_train)
scores = accuracy_score(y_test,rand_f.predict(X_test))
plot_scores_rand.append(scores)
# Out:
# C:\Users\Sean\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:248: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-eb21e56fa24d> in <module>
#       2 rand_f = RandomForestClassifier()
#       3 rand_f.fit(X_train, y_train)
# ----> 4 scores = accuracy_score(y_test,rand_f.predict(X_test))
#       5 plot_scores_rand.append(scores)
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in predict(self, X)
#     543             The predicted classes.
#     544         """
# --> 545         proba = self.predict_proba(X)
#     546
#     547         if self.n_outputs_ == 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in predict_proba(self, X)
#     583         check_is_fitted(self, 'estimators_')
#     584         # Check data
# --> 585         X = self._validate_X_predict(X)
#     586
#     587         # Assign chunk of trees to jobs
#
# ~\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py in _validate_X_predict(self, X)
#     362                                  "call `fit` before exploiting the model.")
#     363
# --> 364         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     365
#     366     @property
#
# ~\Anaconda3\lib\site-packages\sklearn\tree\tree.py in _validate_X_predict(self, X, check_input)
#     374         """Validate X whenever one tries to predict, apply, predict_proba"""
#     375         if check_input:
# --> 376             X = check_array(X, dtype=DTYPE, accept_sparse="csr")
#     377             if issparse(X) and (X.indices.dtype != np.intc or
#     378                                 X.indptr.dtype != np.intc):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     575                              " minimum of %d is required%s."
#     576                              % (n_samples, shape_repr, ensure_min_samples,
# --> 577                                 context))
#     578
#     579     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 6)) while a minimum of 1 is required.

# %%
# plot

# %%
#Predictions

y_pred_knn = clf_knn.predict(X_predict)
y_pred_XGB = clf_XGB.predict(X_predict)
y_pred_logreg = clf_logreg.predict(X_predict)

y_pred_randomForest = rand_f.predict(X_predict)

# %%
this_week = result_16[['HomeTeam','AwayTeam']].loc[370:] # 259
this_week['Result_knn']=y_pred_knn
this_week['Result_XGB']=y_pred_XGB
this_week['Result_Random_Forest']=y_pred_randomForest
this_week['Result_logreg']=y_pred_logreg
this_week['Actual_Result']=y_predict

# %%
# Made the following prediction
this_week
# Out:
#            HomeTeam     AwayTeam  Result_XGB  Actual_Result
# 370         Burnley  Bournemouth           1             -1
# 371  Crystal Palace    West Brom           1              1
# 372    Huddersfield      Arsenal           1             -1
# 373       Liverpool     Brighton           1              1
# 374      Man United      Watford           1              1
# 375       Newcastle      Chelsea           0              1
# 376     Southampton     Man City           0             -1
# 377         Swansea        Stoke           1             -1
# 378       Tottenham    Leicester           1              1
# 379        West Ham      Everton          -1              1

# %%
# Converts numeric result back into a character
# For easier viewing 
def transformResultBack(row,col_name):
    if(row[col_name] == 1):
        return 'H'
    elif(row[col_name] == -1):
        return 'A'
    else:
        return 'D'

# %%
this_week["Actual_Result"] = this_week.apply(lambda row: transformResultBack(row,"Actual_Result"),axis=1)


this_week["Res_knn"] = this_week.apply(lambda row: transformResultBack(row,"Result_knn"),axis=1)
this_week["Res_XGB"] = this_week.apply(lambda row: transformResultBack(row,"Result_XGB"),axis=1)
this_week["Res_logreg"] = this_week.apply(lambda row: transformResultBack(row,"Result_logreg"),axis=1)
this_week["Res_Random_Forest"] = this_week.apply(lambda row: transformResultBack(row,"Result_Random_Forest"),axis=1)


this_week.drop(["Result_knn", "Result_XGB","Result_logreg","Result_Random_Forest"],axis=1,inplace=True)

# %%
# Showing the last 10 results. 
# Showing the actual result and the XGBoost classifier prediction. 
this_week
# Out:
#            HomeTeam     AwayTeam Actual_Result Res_XGB
# 370         Burnley  Bournemouth             A       H
# 371  Crystal Palace    West Brom             H       H
# 372    Huddersfield      Arsenal             A       H
# 373       Liverpool     Brighton             H       H
# 374      Man United      Watford             H       H
# 375       Newcastle      Chelsea             H       D
# 376     Southampton     Man City             A       D
# 377         Swansea        Stoke             A       H
# 378       Tottenham    Leicester             H       H
# 379        West Ham      Everton             H       A

# %%
# Point One
# Picking randomly - Win, Draw, Lose - 33% accuracy
# So there is an improvement

# Point Two
# Premier league is hard to predict.
# The fact that Leicester won the Premier League in 2015-2016, 
# XGBoost gettting 6/10 games right is impressive for the size of the 
# dataset

# Point Three
# Previously dominant teams such as Manchester United and Chelsea
# losing their strength.

# Point Four
# https://www.football.london/reading-fc/how-david-prutton-rates-pundit-15149366
# Mark Lawrenson accuracy - 48%
# Champion pundit - David Prutton accuracy - 46%
# http://eightyfivepoints.blogspot.com/2017/07/how-are-lawrenson-and-merson-beating.html
# Paul Merson accuracy - 52%

# %%
# Season 2018-2019 
# Correct results
# 259 - XGB, RandomForest
# 260 - XGB, 
# 261 - KNN, XGB, Logreg, Random Forest 
# 262 - KNN, XGB, Logreg, Random
# 263 - None
# 264 - None
# 265 - All were right
# 266 - All were right
# 267 - KNN, Logreg, Random Forest was right
# 268 - None 

# KNN - 5/10
# XGB - 6/10
# Logreg - 5/10
# Random Forest - 6/10

# %%
# Season 2017-2018
# Correct results
# 370 - KNN, XGB, random_forest
# 371 - KNN, XGB, Logreg, Random Forest  
# 372 - KNN, logreg
# 373 - KNN, XGB, Logreg, Random Forest  
# 374 - XGB, logreg
# 375 - KNN, logreg
# 376 - logreg, random_forest
# 377 - None
# 378 - XGB, logreg, random_forest
# 379 - None

# KNN - 5/10
# XGB - 5/10
# Logreg - 7/10
# Random Forest - 5/10

# %%
# Season 2016-2017
# Correct results
# 370 - KNN, XGB, logreg, random_forest
# 371 - KNN, XGB, logreg, random_forest
# 372 - KNN, XGB, logreg, random_forest
# 373 - KNN, XGB, logreg
# 374 - None
# 375 - KNN, XGB, logreg
# 376 - None
# 377 - None
# 378 - None
# 379 - KNN, XGB, logreg, random_forest

# KNN - 6/10
# XGB - 6/10
# Logreg - 6/10
# Random Forest - 4/10

# %%
# Next - K-Nearest-Neighbor, Logistic Regression, Random Forest

# %%
# Talk about more rows of data to predict
# It shows good accuracy for the amount of data I have
